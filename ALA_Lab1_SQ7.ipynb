# %% [markdown]
# <a href="https://colab.research.google.com/github/PreranaRaoAdyapady1910/ALA-MSIS/blob/main/ALA_Lab1_SQ7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from vec import Vec
import timeit
import platform

sizes = [2000, 4000, 8000, 16000, 32000, 64000]


def get_time(operation):
    runs = 10
    result = timeit.timeit(operation, number=runs)
    return result / runs


def test_inplace_multiply(vector):
    copy = Vec(vector.elements)
    copy *= 2


def test_inplace_add(vector1, vector2):
    copy = Vec(vector1.elements)
    copy += vector2


for size in sizes:
    vector1 = Vec.uniform(size)
    vector2 = Vec.uniform(size)

    timings = {
        "Addition": get_time(lambda: vector1 + vector2),
        "Subtraction": get_time(lambda: vector1 - vector2),
        "Multiplication": get_time(lambda: 2 * vector1),
        "In-place multiplication": get_time(
            lambda: test_inplace_multiply(vector1)
        ),
        "In-place addition": get_time(
            lambda: test_inplace_add(vector1, vector2)
        ),
        "Negation": get_time(lambda: -vector1),
        "Norm": get_time(lambda: vector1.norm())
    }

    print("\n" + "-" * 50)
    print(f"Vector dimension: {size}")
    print("-" * 50)

    for operation, elapsed in timings.items():
        print(f"{operation:<25} {elapsed:.8f} seconds")
# Out:
# --------------------------------------------------
# Vector dimension: 2000
# --------------------------------------------------
# Addition                  0.00180690 seconds
# Subtraction               0.00286506 seconds
# Multiplication            0.00151881 seconds
# In-place multiplication   0.00144904 seconds
# In-place addition         0.00140922 seconds
# Negation                  0.00027900 seconds
# Norm                      0.00006008 seconds
#
# --------------------------------------------------
# Vector dimension: 4000
# --------------------------------------------------
# Addition                  0.00278428 seconds
# Subtraction               0.00306015 seconds
# Multiplication            0.00269322 seconds
# In-place multiplication   0.00285589 seconds
# In-place addition         0.00299420 seconds
# Negation                  0.00066745 seconds
# Norm                      0.00013926 seconds
#
# --------------------------------------------------
# Vector dimension: 8000
# --------------------------------------------------
# Addition                  0.00598834 seconds
# Subtraction               0.00585514 seconds
# Multiplication            0.00547295 seconds
# In-place multiplication   0.00575188 seconds
# In-place addition         0.00591273 seconds
# Negation                  0.00107184 seconds
# Norm                      0.00023249 seconds
#
# --------------------------------------------------
# Vector dimension: 16000
# --------------------------------------------------
# Addition                  0.01125980 seconds
# Subtraction               0.01226567 seconds
# Multiplication            0.01084569 seconds
# In-place multiplication   0.01174441 seconds
# In-place addition         0.01304784 seconds
# Negation                  0.00223186 seconds
# Norm                      0.00046585 seconds
#
# --------------------------------------------------
# Vector dimension: 32000
# --------------------------------------------------
# Addition                  0.02299146 seconds
# Subtraction               0.02396523 seconds
# Multiplication            0.02190316 seconds
# In-place multiplication   0.02492099 seconds
# In-place addition         0.02379915 seconds
# Negation                  0.00442188 seconds
# Norm                      0.00091766 seconds
#
# --------------------------------------------------
# Vector dimension: 64000
# --------------------------------------------------
# Addition                  0.04507280 seconds
# Subtraction               0.04903563 seconds
# Multiplication            0.04314581 seconds
# In-place multiplication   0.04789666 seconds
# In-place addition         0.04668050 seconds
# Negation                  0.00911383 seconds
# Norm                      0.00185777 seconds
